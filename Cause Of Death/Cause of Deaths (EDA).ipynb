# %%
import pandas as pd
import numpy as np

# %%
dataset = pd.read_csv('cause_of_deaths dataset.csv')

# %%
dataset.head()
# Out:
#   Country/Territory Code  Year  Meningitis  \
# 0       Afghanistan  AFG  1990        2159
# 1       Afghanistan  AFG  1991        2218
# 2       Afghanistan  AFG  1992        2475
# 3       Afghanistan  AFG  1993        2812
# 4       Afghanistan  AFG  1994        3027
#
#    Alzheimer's Disease and Other Dementias  Parkinson's Disease  \
# 0                                     1116                  371
# 1                                     1136                  374
# 2                                     1162                  378
# 3                                     1187                  384
# 4                                     1211                  391
#
#    Nutritional Deficiencies  Malaria  Drowning  Interpersonal Violence  ...  \
# 0                      2087       93      1370                    1538  ...
# 1                      2153      189      1391                    2001  ...
# 2                      2441      239      1514                    2299  ...
# ...

# %%
dataset.tail()
# Out:
#      Country/Territory Code  Year  Meningitis  \
# 6115          Zimbabwe  ZWE  2015        1439
# 6116          Zimbabwe  ZWE  2016        1457
# 6117          Zimbabwe  ZWE  2017        1460
# 6118          Zimbabwe  ZWE  2018        1450
# 6119          Zimbabwe  ZWE  2019        1450
#
#       Alzheimer's Disease and Other Dementias  Parkinson's Disease  \
# 6115                                      754                  215
# 6116                                      767                  219
# 6117                                      781                  223
# 6118                                      795                  227
# 6119                                      812                  232
#
#       Nutritional Deficiencies  Malaria  Drowning  Interpersonal Violence  \
# 6115                      3019     2518       770                    1302
# 6116                      3056     2050       801                    1342
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6120 entries, 0 to 6119
# Data columns (total 34 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Country/Territory                           6120 non-null   object
#  1   Code                                        6120 non-null   object
#  2   Year                                        6120 non-null   int64
#  3   Meningitis                                  6120 non-null   int64
#  4   Alzheimer's Disease and Other Dementias     6120 non-null   int64
#  5   Parkinson's Disease                         6120 non-null   int64
#  6   Nutritional Deficiencies                    6120 non-null   int64
#  7   Malaria                                     6120 non-null   int64
#  8   Drowning                                    6120 non-null   int64
#  9   Interpersonal Violence                      6120 non-null   int64
# ...

# %% [markdown]
# From the above information we can see that there are total **34 columns and 6120 rows/enteries** in the dataset.
#
# Out of which categorical columns 'Country/Territory' and 'Code' seems to be reflecting same information. From which one can be dropped. The other categorical column is year because it's numerical values have not statistical significance.
#
# Remaining 31 columns contains numerical data.

# %%
dataset['Country/Territory'].nunique()
# Out:
# 204

# %%
dataset['Code'].nunique()
# Out:
# 204

# %% [markdown]
# We have verified that the country and code are showing same information.

# %%
# So we can drop code.
dataset = dataset.drop('Code',axis = 1)

# %%
dataset.head()
# Out:
#   Country/Territory  Year  Meningitis  \
# 0       Afghanistan  1990        2159
# 1       Afghanistan  1991        2218
# 2       Afghanistan  1992        2475
# 3       Afghanistan  1993        2812
# 4       Afghanistan  1994        3027
#
#    Alzheimer's Disease and Other Dementias  Parkinson's Disease  \
# 0                                     1116                  371
# 1                                     1136                  374
# 2                                     1162                  378
# 3                                     1187                  384
# 4                                     1211                  391
#
#    Nutritional Deficiencies  Malaria  Drowning  Interpersonal Violence  \
# 0                      2087       93      1370                    1538
# 1                      2153      189      1391                    2001
# 2                      2441      239      1514                    2299
# ...

# %%
dataset.Year.nunique()
# Out:
# 30

# %% [markdown]
# This shows that we have a dataset for a span of 30 years.

# %%
dataset.Year.unique()
# Out:
# array([1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000,
#        2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011,
#        2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019], dtype=int64)

# %% [markdown]
# This dataset has data from 1990 to 2019.

# %%
dataset.drop('Year', axis = 1).describe()
# Out:
#          Meningitis  Alzheimer's Disease and Other Dementias  \
# count   6120.000000                              6120.000000
# mean    1719.701307                              4864.189379
# std     6672.006930                             18220.659072
# min        0.000000                                 0.000000
# 25%       15.000000                                90.000000
# 50%      109.000000                               666.500000
# 75%      847.250000                              2456.250000
# max    98358.000000                            320715.000000
#
#        Parkinson's Disease  Nutritional Deficiencies        Malaria  \
# count          6120.000000               6120.000000    6120.000000
# mean           1173.169118               2253.600000    4140.960131
# std            4616.156238              10483.633601   18427.753137
# min               0.000000                  0.000000       0.000000
# 25%              27.000000                  9.000000       0.000000
# ...

# %%
dataset.isnull().sum()
# Out:
# Country/Territory                             0
# Year                                          0
# Meningitis                                    0
# Alzheimer's Disease and Other Dementias       0
# Parkinson's Disease                           0
# Nutritional Deficiencies                      0
# Malaria                                       0
# Drowning                                      0
# Interpersonal Violence                        0
# Maternal Disorders                            0
# HIV/AIDS                                      0
# Drug Use Disorders                            0
# Tuberculosis                                  0
# Cardiovascular Diseases                       0
# Lower Respiratory Infections                  0
# Neonatal Disorders                            0
# Alcohol Use Disorders                         0
# Self-harm                                     0
# Exposure to Forces of Nature                  0
# Diarrheal Diseases                            0
# ...

# %% [markdown]
# _There are no null vaules in the dataset._

# %% [markdown]
# Now let's start with some exploratory analysis.

# %%
dataset.head(1)
# Out:
#   Country/Territory  Year  Meningitis  \
# 0       Afghanistan  1990        2159
#
#    Alzheimer's Disease and Other Dementias  Parkinson's Disease  \
# 0                                     1116                  371
#
#    Nutritional Deficiencies  Malaria  Drowning  Interpersonal Violence  \
# 0                      2087       93      1370                    1538
#
#    Maternal Disorders  ...  Diabetes Mellitus  Chronic Kidney Disease  \
# 0                2655  ...               2108                    3709
#
#    Poisonings  Protein-Energy Malnutrition  Road Injuries  \
# 0         338                         2054           4154
#
#    Chronic Respiratory Diseases  Cirrhosis and Other Chronic Liver Diseases  \
# 0                          5945                                        2673
#
#    Digestive Diseases  Fire, Heat, and Hot Substances  Acute Hepatitis
# 0                5005                             323             2985
#
# [1 rows x 33 columns]

# %% [markdown]
# ### Finding Top diseases from 1990 - 2019

# %%
disease = dataset.drop(['Country/Territory', 'Year'], axis = 1)

# %%
disease
# Out:
#       Meningitis  Alzheimer's Disease and Other Dementias  \
# 0           2159                                     1116
# 1           2218                                     1136
# 2           2475                                     1162
# 3           2812                                     1187
# 4           3027                                     1211
# ...          ...                                      ...
# 6115        1439                                      754
# 6116        1457                                      767
# 6117        1460                                      781
# 6118        1450                                      795
# 6119        1450                                      812
#
#       Parkinson's Disease  Nutritional Deficiencies  Malaria  Drowning  \
# 0                     371                      2087       93      1370
# 1                     374                      2153      189      1391
# ...

# %%
Disease = pd.DataFrame(disease.columns)

Disease.columns = ['Disease']

# %%
deaths = pd.DataFrame(np.sum(disease.values, axis=0), columns=['Deaths'])

# %%
Disease['Deaths'] = deaths['Deaths']

# %%
Disease
# Out:
#                                        Disease     Deaths
# 0                                   Meningitis   10524572
# 1      Alzheimer's Disease and Other Dementias   29768839
# 2                          Parkinson's Disease    7179795
# 3                     Nutritional Deficiencies   13792032
# 4                                      Malaria   25342676
# 5                                     Drowning   10301999
# 6                       Interpersonal Violence   12752839
# 7                           Maternal Disorders    7727046
# 8                                     HIV/AIDS   36364419
# 9                           Drug Use Disorders    2656121
# 10                                Tuberculosis   45850603
# 11                     Cardiovascular Diseases  447741982
# 12                Lower Respiratory Infections   83770038
# 13                          Neonatal Disorders   76860729
# 14                       Alcohol Use Disorders    4819018
# ...

# %%
Disease = Disease.sort_values(by=['Deaths'],ascending=False).reset_index().drop('index', axis = 1)

Disease['Deaths (in millions)'] = round(Disease['Deaths']/1000000,2)

Disease = Disease.drop('Deaths', axis = 1)

Disease
# Out:
#                                        Disease  Deaths (in millions)
# 0                      Cardiovascular Diseases                447.74
# 1                                    Neoplasms                229.76
# 2                 Chronic Respiratory Diseases                104.61
# 3                 Lower Respiratory Infections                 83.77
# 4                           Neonatal Disorders                 76.86
# 5                           Diarrheal Diseases                 66.24
# 6                           Digestive Diseases                 65.64
# 7                                 Tuberculosis                 45.85
# 8   Cirrhosis and Other Chronic Liver Diseases                 37.48
# 9                                     HIV/AIDS                 36.36
# 10                               Road Injuries                 36.30
# 11                           Diabetes Mellitus                 31.45
# 12     Alzheimer's Disease and Other Dementias                 29.77
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(20,20))
sns.set(font_scale = 1.7)
ax = sns.barplot(x = 'Deaths (in millions)', y = 'Disease', data = Disease)
plt.xlabel('Deaths (in Millions)', fontsize=30);
plt.ylabel('Diseases', fontsize=30);
plt.title('Top Deaths in Past 30 Years (1990-2019)', fontsize=30)
plt.tick_params(labelsize=20)
ax.bar_label(ax.containers[0])
plt.show()

# %% [markdown]
# ### Top 5 Death causing Diseases are:
# 1. Cardiovascular Diseases
# 2. Neoplasms
# 3. Chronic Respiratory Diseases
# 4. Lower Respiratory Diseases
# 5. Neonatal Disorders

# %% [markdown]
# ##### We can see that Cardiovascular Diseases are the most prominent reason for death and it is almost twice of Neoplasms - the second most death causing disease.

# %% [markdown]
# ### Top countries with maximum number of deaths over the period of 1990 - 2019

# %%
dataset.head(1)
# Out:
#   Country/Territory  Year  Meningitis  \
# 0       Afghanistan  1990        2159
#
#    Alzheimer's Disease and Other Dementias  Parkinson's Disease  \
# 0                                     1116                  371
#
#    Nutritional Deficiencies  Malaria  Drowning  Interpersonal Violence  \
# 0                      2087       93      1370                    1538
#
#    Maternal Disorders  ...  Diabetes Mellitus  Chronic Kidney Disease  \
# 0                2655  ...               2108                    3709
#
#    Poisonings  Protein-Energy Malnutrition  Road Injuries  \
# 0         338                         2054           4154
#
#    Chronic Respiratory Diseases  Cirrhosis and Other Chronic Liver Diseases  \
# 0                          5945                                        2673
#
#    Digestive Diseases  Fire, Heat, and Hot Substances  Acute Hepatitis
# 0                5005                             323             2985
#
# [1 rows x 33 columns]

# %%
country = dataset.drop('Year',axis = 1)

# %%
country = country.groupby('Country/Territory').sum().reset_index()

# %%
country['Deaths'] = country.drop('Country/Territory', axis = 1).sum(axis = 1)

# %%
country
# Out:
#     Country/Territory  Meningitis  Alzheimer's Disease and Other Dementias  \
# 0         Afghanistan       78666                                    41998
# 1             Albania        1323                                    16549
# 2             Algeria       15685                                    86914
# 3      American Samoa          30                                      143
# 4             Andorra           0                                      614
# ..                ...         ...                                      ...
# 199         Venezuela       11615                                   108735
# 200           Vietnam       38559                                   369363
# 201             Yemen       21095                                    31045
# 202            Zambia       98886                                    13473
# 203          Zimbabwe       41238                                    20017
#
# ...

# %%
top_country = country[['Country/Territory', 'Deaths']].sort_values(by=['Deaths'],ascending=False)[:10]

# %%
top_country
# Out:
#     Country/Territory     Deaths
# 37              China  265408106
# 81              India  238158165
# 194     United States   71197802
# 149            Russia   59591155
# 82          Indonesia   44046941
# 129           Nigeria   43670014
# 136          Pakistan   38151878
# 25             Brazil   32674112
# 89              Japan   31922807
# 67            Germany   25559667

# %%
top_country['Deaths (in millions)'] = round(top_country['Deaths']/1000000, 2)

top_country = top_country.drop('Deaths', axis = 1)

top_country.index = range(1, 11)

top_country
# Out:
#    Country/Territory  Deaths (in millions)
# 1              China                265.41
# 2              India                238.16
# 3      United States                 71.20
# 4             Russia                 59.59
# 5          Indonesia                 44.05
# 6            Nigeria                 43.67
# 7           Pakistan                 38.15
# 8             Brazil                 32.67
# 9              Japan                 31.92
# 10           Germany                 25.56

# %%
plt.figure(figsize=(15,8))
sns.set(font_scale = 1.7)
ax = sns.barplot(x = 'Deaths (in millions)', y = 'Country/Territory', data = top_country)
plt.title('Total Deaths in Past 30 Years (1990-2019) vs Top 10 Countries', fontsize=30)
ax.bar_label(ax.containers[0])
plt.show()

# %% [markdown]
# ### From the above bar plot we can see that China has most number of deaths with 265.41 million deaths followed by India with 238.16 million deaths. The United States is at 3rd position but the difference is huge between 2nd and 3rd position, the US has almost 1/3rd deaths occured in India.
#
# The most populated state is China followed by India and United States as of the 2019 population data. Hence, we can see a direction relation with the population of the country.

# %% [markdown]
# ### Now let's see yearly report for top 3 countries.

# %%
sum_disease = dataset

# %%
sum_disease['Deaths'] = sum_disease.sum(axis = 1)
# Out:
# C:\Users\katiy\AppData\Local\Temp/ipykernel_16652/2102011521.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   sum_disease['Deaths'] = sum_disease.sum(axis = 1)

# %%
sum_disease = sum_disease.drop(disease.columns, axis = 1)

# %%
sum_disease
# Out:
#      Country/Territory  Year  Deaths
# 0          Afghanistan  1990  149961
# 1          Afghanistan  1991  158835
# 2          Afghanistan  1992  171148
# 3          Afghanistan  1993  184223
# 4          Afghanistan  1994  196789
# ...                ...   ...     ...
# 6115          Zimbabwe  2015  132095
# 6116          Zimbabwe  2016  130290
# 6117          Zimbabwe  2017  128532
# 6118          Zimbabwe  2018  125524
# 6119          Zimbabwe  2019  125559
#
# [6120 rows x 3 columns]

# %%
top_country_sum_disease = sum_disease[sum_disease['Country/Territory'].isin(["China", "India", "United States"])]

# %%
top_country_sum_disease.rename(columns = {'Country/Territory':'Country'}, inplace = True)
# Out:
# C:\Users\katiy\anaconda3\lib\site-packages\pandas\core\frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
top_country_sum_disease
# Out:
#             Country  Year   Deaths
# 1110          China  2007  8757208
# 1111          China  2008  8974678
# 1112          China  2009  9076842
# 1113          China  2010  9286674
# 1114          China  2011  9368985
# ...             ...   ...      ...
# 5845  United States  2005  2354259
# 5846  United States  2006  2351970
# 5847  United States  2017  2685838
# 5848  United States  2018  2764000
# 5849  United States  2019  2836983
#
# [90 rows x 3 columns]

# %%
from pandasql import sqldf

# %%
q = 'select * from top_country_sum_disease where Country == "China"';
china = sqldf(q)

china['Deaths (in millions)'] = round(china['Deaths']/1000000, 2)

china = china.drop('Deaths', axis = 1)

china
# Out:
#    Country  Year  Deaths (in millions)
# 0    China  2007                  8.76
# 1    China  2008                  8.97
# 2    China  2009                  9.08
# 3    China  2010                  9.29
# 4    China  2011                  9.37
# 5    China  2012                  9.37
# 6    China  2013                  9.41
# 7    China  2014                  9.51
# 8    China  2015                  9.59
# 9    China  2016                  9.82
# 10   China  1990                  7.97
# 11   China  1991                  8.04
# 12   China  1992                  8.06
# 13   China  1993                  8.08
# 14   China  1994                  8.07
# 15   China  1995                  8.07
# 16   China  1996                  8.08
# 17   China  1997                  8.05
# 18   China  1998                  8.08
# 19   China  1999                  8.21
# 20   China  2000                  8.41
# 21   China  2001                  8.49
# 22   China  2002                  8.61
# ...

# %%
plt.figure(figsize=(12,6))
sns.scatterplot(x = 'Year', y = 'Deaths (in millions)', data = china)
plt.title('Total Deaths in Past 30 Years (1990-2019) in "CHINA" vs Year', fontsize=25)
plt.show()

# %%
q = 'select * from top_country_sum_disease where Country == "India"';
india = sqldf(q)

india['Deaths (in millions)'] = round(india['Deaths']/1000000, 2)

india = india.drop('Deaths', axis = 1)

india
# Out:
#    Country  Year  Deaths (in millions)
# 0    India  2007                  8.02
# 1    India  2008                  8.16
# 2    India  2009                  8.00
# 3    India  2012                  8.25
# 4    India  2013                  8.38
# 5    India  2015                  8.40
# 6    India  1990                  7.47
# 7    India  1991                  7.55
# 8    India  1992                  7.62
# 9    India  1993                  7.54
# 10   India  1994                  7.46
# 11   India  1995                  7.41
# 12   India  1996                  7.47
# 13   India  1997                  7.75
# 14   India  1998                  7.83
# 15   India  1999                  7.76
# 16   India  2000                  7.77
# 17   India  2001                  7.85
# 18   India  2002                  7.83
# 19   India  2003                  7.71
# 20   India  2004                  7.55
# 21   India  2005                  7.69
# 22   India  2006                  7.88
# ...

# %%
plt.figure(figsize=(12,6))
sns.scatterplot(x = 'Year', y = 'Deaths (in millions)', data = india)
plt.title('Total Deaths in Past 30 Years (1990-2019) in "INDIA" vs Year', fontsize=25)
plt.show()

# %%
q = 'select * from top_country_sum_disease where Country == "United States"';
usa = sqldf(q)

usa['Deaths (in millions)'] = round(usa['Deaths']/1000000, 2)

usa = usa.drop('Deaths', axis = 1)

usa
# Out:
#           Country  Year  Deaths (in millions)
# 0   United States  2007                  2.35
# 1   United States  2008                  2.37
# 2   United States  2009                  2.37
# 3   United States  2010                  2.38
# 4   United States  2011                  2.43
# 5   United States  2012                  2.46
# 6   United States  2013                  2.50
# 7   United States  2014                  2.54
# 8   United States  2015                  2.60
# 9   United States  2016                  2.66
# 10  United States  1990                  2.07
# 11  United States  1991                  2.09
# 12  United States  1992                  2.11
# 13  United States  1993                  2.18
# 14  United States  1994                  2.21
# 15  United States  1995                  2.24
# 16  United States  1996                  2.24
# 17  United States  1997                  2.23
# 18  United States  1998                  2.25
# ...

# %%
plt.figure(figsize=(12,6))
sns.scatterplot(x = 'Year', y = 'Deaths (in millions)', data = usa)
plt.title('Total Deaths in Past 30 Years (1990-2019) in "UNITED STATES" vs Year', fontsize=25)
plt.show()

# %% [markdown]
# ### Now let's see top 3 diseases yearly deaths

# %%
yearly_data = dataset.drop('Country/Territory', axis = 1)

# %%
yearly_data = yearly_data.groupby('Year').sum().reset_index()

# %%
top_disease_yearly_data = yearly_data[['Year', 'Cardiovascular Diseases', 'Neoplasms', 'Chronic Respiratory Diseases']]

# %%
df = top_disease_yearly_data[['Cardiovascular Diseases', 'Neoplasms', 'Chronic Respiratory Diseases']].transform(func = lambda x : round(x/1000000, 2))

df.columns = ['Cardiovascular Diseases (in millions)', 'Neoplasms (in millions)', 'Chronic Respiratory Diseases (in millions)']

df['Year'] = top_disease_yearly_data['Year']

# %%
df
# Out:
#     Cardiovascular Diseases (in millions)  Neoplasms (in millions)  \
# 0                                   12.06                     5.75
# 1                                   12.22                     5.87
# 2                                   12.44                     6.00
# 3                                   12.80                     6.17
# 4                                   13.03                     6.30
# 5                                   13.13                     6.40
# 6                                   13.21                     6.49
# 7                                   13.34                     6.59
# 8                                   13.46                     6.70
# 9                                   13.72                     6.86
# 10                                  13.96                     7.00
# 11                                  14.19                     7.11
# 12                                  14.50                     7.25
# ...

# %%
plt.figure(figsize=(16,6))
sns.scatterplot(x = 'Year', y = 'Cardiovascular Diseases (in millions)', data = df)
plt.title('Total Deaths in Past 30 Years (1990-2019) by "Cardiovascular Diseases" vs Year', fontsize=25)
plt.show()

# %%
plt.figure(figsize=(16,6))
sns.scatterplot(x = 'Year', y = 'Neoplasms (in millions)', data = df)
plt.title('Total Deaths in Past 30 Years (1990-2019) by "Neoplasms" vs Year', fontsize=25)
plt.show()

# %%
plt.figure(figsize=(16,6))
sns.scatterplot(x = 'Year', y = 'Chronic Respiratory Diseases (in millions)', data = df)
plt.title('Total Deaths by "Chronic Respiratory Diseases" vs Year', fontsize=25)
plt.show()
